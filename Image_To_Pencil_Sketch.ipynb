# %% [markdown]
# # Description

# %% [markdown]
# #### LetsGrowMore :- Data Science Intern
#
# #### LGM(VIP) January Batch-2022
#
# #### Task - Image to pencil sketch using python
#
# #### Goal - We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.
#
# #### Author:- Manav Khakhi

# %% [markdown]
# # Importing Required Libraries

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# # Uploading & Reading the Image

# %%
original_img = cv2.imread('/content/Khakhi Manav_Photo(1).jpeg')

# %% [markdown]
# # Displaying the Uploaded Image

# %%
cv2_imshow(original_img)
# Out:
# <PIL.Image.Image image mode=RGB size=481x561 at 0x7F3F57D1A9D0>

# %% [markdown]
# # Reading the Uploaded Image in RGB format

# %%
RGB_image = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_image)
plt.axis(False)
plt.savefig('rgbimg.png')
plt.show()

# %% [markdown]
# # Converting & Displaying the RGB Image Format into Gray Scale Image

# %%
gray_scale_image = cv2.cvtColor(RGB_image,cv2.COLOR_BGR2GRAY) 
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=481x561 at 0x7F3F57D15350>

# %% [markdown]
# # Inverting & Displaying the Gray Scale Image

# %%
inverted_image = cv2.bitwise_not(gray_scale_image)  
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=481x561 at 0x7F3F57C65490>

# %% [markdown]
# # Smoothing the Inverted Gray Scale Image & Displaying it

# %%
image_smoothing = cv2.GaussianBlur(inverted_image, (21, 21), sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=481x561 at 0x7F3F57C72210>

# %% [markdown]
# # Pencil Sketch Function

# %%
def pencil_sketch(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %% [markdown]
# # Pencil Sketching the Image using the above defined function

# %%
pencil_sketch = pencil_sketch(gray_scale_image,image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=481x561 at 0x7F3F57C6CC90>

# %% [markdown]
# # Displaying the Original Image vs Pencil Sketched Image

# %%
cv2_imshow(original_img)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=481x561 at 0x7F3F57C65B10>
# <PIL.Image.Image image mode=L size=481x561 at 0x7F3F57C65BD0>

# %% [markdown]
# ![thank-you-hand-drawn-lettering-260nw-1263463690.jpg](data:image/jpeg;base64,...)
